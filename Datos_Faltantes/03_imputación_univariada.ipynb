# %% [markdown]
# ### Técnicas de imputación ***Univariada***

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

def graficar_serie(df, obs = '', titulo=''):
    '''
    Graficar la serie y ver sus valores extremos
    Params:
        - df    : DataFrame de Pandas con la serie de tiempo
        - obs   : Nombre de la columna a graficar
        - titulo: Título del gráfico
    '''

    fig, ax = plt.subplots(1, 1)

    if type(df) == pd.DataFrame:
        ax = sns.pointplot(data = df, x = df.index, y = obs, markers='')
    else:
        df = df.to_frame(name = obs)
        ax = sns.pointplot(data = df, x = df.index, y = obs, markers='')
    
    n_ticks = 10
    locator = mdates.AutoDateLocator(maxticks = n_ticks)
    ax.xaxis.set_major_locator(locator)

    plt.xticks(rotation = 45)
    
    ax.set_xlabel('Tiempo')
    ax.set_ylabel(obs)
    ax.set_title(titulo)

# %% [markdown]
# ### Imputación ***Univariada***
#
# * Realizar imputación por la media
# * Realizar imputación por llenado hacia adelante
# * Realizar imputación por llenado hacia atrás

# %% [markdown]
# #### Imputación por la media

# %%
co2 = pd.read_csv('datos/co2_faltantes.csv',
                    parse_dates = ['año'], 
                    index_col = 'año')

graficar_serie(co2, obs = 'co2', titulo = 'C02')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 5
#       1 co2 = pd.read_csv('datos/co2_faltantes.csv',
#       2                     parse_dates = ['año'],
#       3                     index_col = 'año')
# ----> 5 graficar_serie(co2, obs = 'co2', titulo = 'C02')
#
# Cell In[29], line 31, in graficar_serie(df, obs, titulo)
#      29 plt.xlabel('Tiempo')
#      30 plt.ylabel(obs)
# ---> 31 plt.title(titulo)
#
# TypeError: 'str' object is not callable

# %%
co2 = pd.read_csv('datos/co2_faltantes.csv',
                    parse_dates = ['año'], 
                    index_col = 'año')
graficar_serie(co2, obs = 'co2', titulo = 'C02')

co2_imp = co2['co2'].fillna(co2['co2'].mean())
graficar_serie(co2_imp, obs = 'co2', titulo = 'Imputación por la media')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       1 co2 = pd.read_csv('datos/co2_faltantes.csv',
#       2                     parse_dates = ['año'],
#       3                     index_col = 'año')
# ----> 4 graficar_serie(co2, obs = 'co2', titulo = 'C02')
#       6 co2_imp = co2['co2'].fillna(co2['co2'].mean())
#       7 graficar_serie(co2_imp, obs = 'co2', titulo = 'Imputación por la media')
#
# Cell In[27], line 31, in graficar_serie(df, obs, titulo)
#      29 plt.xlabel('Tiempo')
#      30 plt.ylabel(obs)
# ---> 31 plt.title(titulo)
#
# TypeError: 'str' object is not callable

# %%
clicks = pd.read_csv('datos/clicks_obs_faltantes.csv',
                    parse_dates = ['fecha'], 
                    index_col = 'fecha')
clicks
graficar_serie(clicks, obs = 'clicks', titulo = 'Número de clicks')
# Out:
# /tmp/ipykernel_4847/1027920345.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   clicks = pd.read_csv('datos/clicks_obs_faltantes.csv',
